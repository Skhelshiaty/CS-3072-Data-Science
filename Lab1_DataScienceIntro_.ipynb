# %% [markdown]
# Name: Seifeldin Elshiaty
# Student ID: S23108194
# Course: Data Sciences (CS 3072)
# Lab: Getting Ready (Google Colab)

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
# Create a variable and print it
name = "Effat University"
print("Welcome to", name)

# Simple math in Python
a = 10
b = 5
print("Sum:", a + b)
print("Product:", a * b)

# List practice
my_list = [1, 2, 3, 4, 5]
print("List:", my_list)
print("First element:", my_list[0])
print("Last element:", my_list[-1])
# List practice with strings
fruits = ["apple", "banana", "mango"]
print(fruits[0])   # First element
print(len(fruits)) # Number of items
# Out:
# Welcome to Effat University
# Sum: 15
# Product: 50
# List: [1, 2, 3, 4, 5]
# First element: 1
# Last element: 5
# apple
# 3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4efac13-de4e-4054-b353-f703c45cdc8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4efac13-de4e-4054-b353-f703c45cdc8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.shape)      # rows, columns
print(df.columns)    # column names
# Out:
# (891, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-791585a6-c3a3-45c0-bc0d-568b70ee551a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-791585a6-c3a3-45c0-bc0d-568b70ee551a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df_json = pd.read_json("pokemonDB_dataset.json")

# %%
print("Number of rows:", df_json.shape[0])
# Out:
# Number of rows: 31

# %%
df_json.head(10)
# Out:
#                                                     Abomasnow  \
# Type                                               Grass, Ice
# Species                                    Frost Tree Pokémon
# Height                                          2.2 m (7′03″)
# Weight                                   135.5 kg (298.7 lbs)
# Abilities        1. Snow Warning, Soundproof (hidden ability)
# EV Yield                                  1 Attack, 1 Sp. Atk
# Catch Rate                   60 (7.8% with PokéBall, full HP)
# Base Friendship                                   50 (normal)
# Base Exp                                                  173
# Growth Rate                                              Slow
#
#                                    Mega Abomasnow  \
# Type                                   Grass, Ice
# Species                        Frost Tree Pokémon
# Height                              2.7 m (8′10″)
# Weight                       185.0 kg (407.9 lbs)
# ...

# %%
df_json = pd.read_json("pokemonDB_dataset.json").T
df_json.head()
# Out:
#                       Type             Species         Height  \
# Abomasnow       Grass, Ice  Frost Tree Pokémon  2.2 m (7′03″)
# Mega Abomasnow  Grass, Ice  Frost Tree Pokémon  2.7 m (8′10″)
# Abra               Psychic         Psi Pokémon  0.9 m (2′11″)
# Absol                 Dark    Disaster Pokémon  1.2 m (3′11″)
# Mega Absol            Dark    Disaster Pokémon  1.2 m (3′11″)
#
#                               Weight  \
# Abomasnow       135.5 kg (298.7 lbs)
# Mega Abomasnow  185.0 kg (407.9 lbs)
# Abra              19.5 kg (43.0 lbs)
# Absol            47.0 kg (103.6 lbs)
# Mega Absol       49.0 kg (108.0 lbs)
#
#                                                         Abilities  \
# Abomasnow            1. Snow Warning, Soundproof (hidden ability)
# Mega Abomasnow                                    1. Snow Warning
# Abra            1. Synchronize, 2. Inner Focus, Magic Guard (h...
# Absol           1. Pressure, 2. Super Luck, Justified (hidden ...
# ...

# %%
print(df_json.shape)      # rows, columns
print(df_json.columns)    # column names
# Out:
# (1215, 31)
# Index(['Type', 'Species', 'Height', 'Weight', 'Abilities', 'EV Yield',
#        'Catch Rate', 'Base Friendship', 'Base Exp', 'Growth Rate',
#        'Egg Groups', 'Gender', 'Egg Cycles', 'HP Base', 'HP Min', 'HP Max',
#        'Attack Base', 'Attack Min', 'Attack Max', 'Defense Base',
#        'Defense Min', 'Defense Max', 'Special Attack Base',
#        'Special Attack Min', 'Special Attack Max', 'Special Defense Base',
#        'Special Defense Min', 'Special Defense Max', 'Speed Base', 'Speed Min',
#        'Speed Max'],
#       dtype='object')

# %%
df_json.describe(include="all")
# Out:
#           Type          Species         Height            Weight    Abilities  \
# count     1215             1215           1215              1215         1215
# unique     221              733             63               527          704
# top     Normal  Paradox Pokémon  0.6 m (2′00″)  0.3 kg (0.7 lbs)  1. Levitate
# freq        82               22             97                15           35
#
#         EV Yield                        Catch Rate Base Friendship Base Exp  \
# count       1215                              1215            1215     1215
# unique        50                                38               9      204
# top     2 Attack  45 (5.9% with PokéBall, full HP)     50 (normal)       60
# freq         124                               381             964       29
#
#         Growth Rate  ... Defense Max Special Attack Base Special Attack Min  \
# count          1215  ...        1215                1215               1215
# ...

# %%
df_json.isnull().sum()
# Out:
# Type                    0
# Species                 0
# Height                  0
# Weight                  0
# Abilities               0
# EV Yield                0
# Catch Rate              0
# Base Friendship         0
# Base Exp                0
# Growth Rate             0
# Egg Groups              0
# Gender                  0
# Egg Cycles              0
# HP Base                 0
# HP Min                  0
# HP Max                  0
# Attack Base             0
# Attack Min              0
# Attack Max              0
# Defense Base            0
# Defense Min             0
# Defense Max             0
# Special Attack Base     0
# Special Attack Min      0
# Special Attack Max      0
# Special Defense Base    0
# Special Defense Min     0
# Special Defense Max     0
# Speed Base              0
# Speed Min               0
# Speed Max               0
# dtype: int64

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7624064d-caa7-4fe4-91f7-216fbf38675d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7624064d-caa7-4fe4-91f7-216fbf38675d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df_excel = pd.read_excel("Titanic-Dataset_converted.xlsx")
df_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_excel.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print(df_excel.shape)      # rows, columns
print(df_excel.columns)    # column names
# Out:
# (891, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_excel.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_excel.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
